# %% [markdown]
# # Modules and imports

# %%
if __name__ == '__main__':
    print('I will run only if you run the script itself')
    print('If you will import me, I will ignore you')
# Out:
# I will run only if you run the script itself
# If you will import me, I will ignore you

# %% [markdown]
# [Proper explanation](https://stackoverflow.com/questions/419163/what-does-if-name-main-do)

# %%
#now imports

# %%
import random #import whole module

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_log',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
from random import randint #import just one function

# %%
random.randint == randint
# Out:
# True

# %%
#you can rename the imported functions or consts

# %%
#saves string.ascii_uppercase as ABCD
from string import ascii_uppercase as ABCD

# %%
ABCD
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
#DON'T EVER DO:
from os import * #can OVERRIDE your function in __main__

# %%
uname()
# Out:
# posix.uname_result(sysname='Linux', nodename='purplehad', release='4.11.6-101.fc24.x86_64', version='#1 SMP Tue Jun 20 16:29:01 UTC 2017', machine='x86_64')

# %%
#When you make a folder with name my_module
#and for example module.py in it
#so the path would be ./my_module/module.py 
#(. being the current directory)
#you would import as
from my_module import module

# %% [markdown]
# # Requests

# %%
#do pip install requests in your virtualenv

# %%
import requests

# %%
requests.get('http://api.fixer.io/latest')
# Out:
# <Response [200]>

# %%
r = requests.get('http://api.fixer.io/latest')

# %%
r
# Out:
# <Response [200]>

# %%
r.ok
# Out:
# True

# %%
r.json()
# Out:
# {'base': 'EUR',
#  'date': '2017-07-11',
#  'rates': {'AUD': 1.4988,
#   'BGN': 1.9558,
#   'BRL': 3.7258,
#   'CAD': 1.4718,
#   'CHF': 1.104,
#   'CNY': 7.7577,
#   'CZK': 26.124,
#   'DKK': 7.4365,
#   'GBP': 0.88318,
#   'HKD': 8.9084,
#   'HRK': 7.411,
#   'HUF': 308.13,
#   'IDR': 15272.0,
#   'ILS': 4.077,
#   'INR': 73.665,
#   'JPY': 130.36,
#   'KRW': 1312.2,
#   'MXN': 20.546,
#   'MYR': 4.9013,
#   'NOK': 9.512,
#   'NZD': 1.5788,
#   'PHP': 57.813,
#   'PLN': 4.246,
#   'RON': 4.5685,
#   'RUB': 69.33,
#   'SEK': 9.639,
#   'SGD': 1.5783,
#   'THB': 38.891,
#   'TRY': 4.1431,
#   'USD': 1.1405,
#   'ZAR': 15.46}}

# %%
r.encoding #is None in this case

# %%
r.headers
# Out:
# {'Content-Length': '441', 'Date': 'Wed, 12 Jul 2017 09:27:10 GMT', 'Content-Type': 'application/json', 'Last-Modified': 'Tue, 11 Jul 2017 00:00:00 GMT', 'Server': 'nginx/1.11.13', 'Cache-Control': 'public, must-revalidate, max-age=900', 'X-Content-Type-Options': 'nosniff', 'Vary': 'Origin', 'Connection': 'Keep-Alive'}

# %%
r.url
# Out:
# 'http://api.fixer.io/latest'

# %%
r.elapsed
# Out:
# datetime.timedelta(0, 5, 155967)

# %%
payload = {'base' : 'CZK'}
r2 = requests.get('http://api.fixer.io/latest', params=payload)

# %%
r2
# Out:
# <Response [200]>

# %%
r2.url
# Out:
# 'http://api.fixer.io/latest?base=CZK'

# %%
r2.json()
# Out:
# {'base': 'CZK',
#  'date': '2017-07-11',
#  'rates': {'AUD': 0.057373,
#   'BGN': 0.074866,
#   'BRL': 0.14262,
#   'CAD': 0.056339,
#   'CHF': 0.04226,
#   'CNY': 0.29696,
#   'DKK': 0.28466,
#   'EUR': 0.038279,
#   'GBP': 0.033807,
#   'HKD': 0.341,
#   'HRK': 0.28369,
#   'HUF': 11.795,
#   'IDR': 584.6,
#   'ILS': 0.15606,
#   'INR': 2.8198,
#   'JPY': 4.99,
#   'KRW': 50.23,
#   'MXN': 0.78648,
#   'MYR': 0.18762,
#   'NOK': 0.36411,
#   'NZD': 0.060435,
#   'PHP': 2.213,
#   'PLN': 0.16253,
#   'RON': 0.17488,
#   'RUB': 2.6539,
#   'SEK': 0.36897,
#   'SGD': 0.060416,
#   'THB': 1.4887,
#   'TRY': 0.15859,
#   'USD': 0.043657,
#   'ZAR': 0.59179}}

# %% [markdown]
# # Unittest

# %% [markdown]
# [informative_video](https://www.youtube.com/watch?v=FxSsnHeWQBY)

# %% [markdown]
# [docs](https://docs.python.org/3.6/library/unittest.html)

# %%
#compare.py and test_compare.py uploaded on slack

# %% [markdown]
# # Subprocess

# %%
import subprocess

# %%
subprocess.call(['ls','-a','-l','-h']) #should return 0
# Out:
# 0

# %%
subprocess.call(['ps', '-aux'])
# Out:
# 0

# %%
v = subprocess.check_output(["echo", "Hello World!"])

# %%
type(v)
# Out:
# bytes

# %%
proc = subprocess.Popen(['uname', '-a'], stdout=subprocess.PIPE)

# %%
proc

# %%
proc.stdout.read()
# Out:
# b'Linux purplehad 4.11.6-101.fc24.x86_64 #1 SMP Tue Jun 20 16:29:01 UTC 2017 x86_64 x86_64 x86_64 GNU/Linux\n'

# %%
proc.returncode

# %%
proc.pid
# Out:
# 28579

# %%
proc.communicate?

# %%
proc.kill?

# %%
proc.kill()

# %%
proc.pid
# Out:
# 29858

# %%
proc.kill()

# %%
proc.communicate()
# Out:
# (b'', None)

# %%
proc = subprocess.Popen(['sudo','systemctl', 'stop', 'sshd'], stdout=subprocess.PIPE)

# %%
proc.stdout.read()
# Out:
# b''

# %%
proc.communicate()
# Out:
# (b'', None)

# %% [markdown]
# # File operations, look for file, find file, get path

# %%
import os

# %%
os.path.exists('namefile.py')
# Out:
# True

# %%
os.getcwd()
# Out:
# '/home/tmikulec/playground/python/edu'

# %%
ls
# Out:
# 01_csv/                                                    input_and_open.py*
# bin/                                                       lib/
# compare.py                                                 lib64@
# CONST.py                                                   namefile.py
# data.dat                                                   new_file.txt
# 'Day1 - almost all the basics from learnpython.org.ipynb'  pip-selfcheck.json
# 'Day2 - 2 Exercises, Try and Except, Classes.ipynb'        __pycache__/
# Day3.ipynb                                                 share/
# empty.py                                                   test_compare.py
# guess_number.py                                            test_folder/
# include/                                                   Untitled.ipynb

# %%
#namefile.py exists here

# %%
os.path.isdir('share')
# Out:
# True

# %%
os.walk(os.getcwd())
# Out:
# <generator object walk at 0x7f459bc19e60>

# %%
for root, dirs, files in os.walk(os.getcwd()):
    print(root) #prints fullpath
    print(dirs) #list of directories in the root
    print(files) #list of files in the root
    input() #for pause, to check the output
# Out:
# /home/tmikulec/playground/python/edu
# ['__pycache__', 'test_folder', '.ipynb_checkpoints', 'lib', 'bin', 'include', 'share', '01_csv', 'lib64']
# ['.compare.py.swp', 'CONST.py', 'test_compare.py', 'compare.py', 'guess_number.py', 'empty.py', 'Day2 - 2 Exercises, Try and Except, Classes.ipynb', '.test_compare.py.swp', 'Untitled.ipynb', 'input_and_open.py', 'Day1 - almost all the basics from learnpython.org.ipynb', 'new_file.txt', 'Day3.ipynb', 'data.dat', 'pip-selfcheck.json', 'namefile.py']
#
# /home/tmikulec/playground/python/edu/__pycache__
# []
# ['compare.cpython-35.pyc', 'empty.cpython-35.pyc', 'CONST.cpython-35.pyc']
#
# /home/tmikulec/playground/python/edu/test_folder
# ['__pycache__']
# ['test_module.py']
#
# /home/tmikulec/playground/python/edu/test_folder/__pycache__
# []
# ['test_module.cpython-35.pyc']
#
# /home/tmikulec/playground/python/edu/.ipynb_checkpoints
# []
# ...

# %%
for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if file.endswith('pyc'):
            fullpath = os.path.join(root, file)
            print(fullpath)
            print(os.path.isfile(fullpath))
            input() # pause so we can check the file
# Out:
# /home/tmikulec/playground/python/edu/__pycache__/compare.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/__pycache__/empty.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/__pycache__/CONST.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/test_folder/__pycache__/test_module.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/copy.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/struct.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/hashlib.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/sre_compile.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/heapq.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/weakref.cpython-35.pyc
# True
# /home/tmikulec/playground/python/edu/lib/python3.5/__pycache__/re.cpython-35.pyc
# True
# ...

# %% [markdown]
# # MatPlotLib

# %%
import numpy as np
# Out:
# ---------------------------------------
# ImportErrorTraceback (most recent call last)
# <ipython-input-106-4ee716103900> in <module>()
# ----> 1 import numpy as np
#
# ImportError: No module named 'numpy'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------
# ImportErrorTraceback (most recent call last)
# <ipython-input-107-eff513f636fd> in <module>()
# ----> 1 import matplotlib.pyplot as plt
#
# ImportError: No module named 'matplotlib'

# %%
#we need to instlal numpy and matplotlib

# %%
import pip; pip.main(['install', 'numpy', 'matplotlib'])
# Out:
# ...
#   Using cached matplotlib-2.0.2-cp35-cp35m-manylinux1_x86_64.whl
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl
# ...
#   Using cached pytz-2017.2-py2.py3-none-any.whl
# ...
#   Using cached pyparsing-2.2.0-py2.py3-none-any.whl
# ...
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Y, X = np.mgrid[-3:3:100j, -3:3:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U*U + V*V)

fig0, ax0 = plt.subplots()
strm = ax0.streamplot(X, Y, U, V, color=U, linewidth=2, cmap=plt.cm.autumn)
fig0.colorbar(strm.lines)

fig1, (ax1, ax2) = plt.subplots(ncols=2)
ax1.streamplot(X, Y, U, V, density=[0.5, 1])

lw = 5*speed / speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)

plt.show()

# %%
#lets do simpler stuff

# %%
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Jerry', 'Dick', 'Harry', 'Slim', 'Jim', 'Jofrey')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center',
        color='green', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs', 'Thing'
sizes = [1500, 30, 45, 10, 30]
explode = (0, 0.1, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
